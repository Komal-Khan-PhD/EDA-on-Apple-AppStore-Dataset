# %% [markdown]
# # 1.0 About Author
# - Project: "Exploratory Data Analysis on Apple AppStore dataset"
# - Author: "Komal Khan"
# - Code Submission Date: "August 19, 2023"
# - Author's Contact Info:
# [<i class="fas fa-envelope"></i>](doctor.engineer.kk@gmail.com),
# [<i class="fab fa-github"></i>](https://github.com/Komal-Khan-PhD),
# [<i class="fab fa-kaggle"></i>](https://www.kaggle.com/drkomalkhan),
# [<i class="fab fa-linkedin"></i>](https://www.linkedin.com/in/komalkhan31),
# [<i class="fab fa-x-twitter"></i>](https://twitter.com/_Komal_Khan),
# [<i class="fab fa-medium"></i>](https://medium.com/@doctor.engineer.kk)
#
# <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.14.0/css/all.css">

# %% [markdown]
# # 2.0 About Data
# - Data: Apple AppStore
# - Data Age: The data was collected in the month of October 2021.
# - **Dataset:** 🔗 [*link*](https://www.kaggle.com/datasets/gauthamp10/apple-appstore-apps)
#
# # 3.0 Task:
# We intend to conduct an Exploratory Data Analysis (EDA) on the given dataset. The EDA will serve as the basis for the necessary Data Wrangling activities to be carried out for the purposes of data cleaning and normalization. During the coding process, we will document our observations. Ultimately, we will produce a summary and draw conclusions from our findings
#
# ### 3.1 Kernel Version Used:
# - Python 3.11.4
#
# # 4.0 Objectives:
# The core objective of this project is to perform an exhaustive analysis of the dataset, uncovering meaningful insights not yet discovered. Our intention is to assist in:
#
# * Increase user engagement and satisfaction.
# * Expand user base in international markets.
# * Improve app's average user rating.
# * Optimize app performance and usability.
# * Boost in-app purchases and revenue.

# %% [markdown]
# # 5.0 Exploratory Data Analysis and Visualization

# %% [markdown]
# ## 5.1 Import libraries
# - We will use the follwoing libraries
#     1. Pandas: Data manipulation and analysis library.
#     2. Numpy: Numerical computing library.
#     3. Matplotlib: Data visualization library.
#     4. Seaborn: Statistical data visualization library.
#     5. Plotly.express: Data visualization library.
#     6. missingno: Missing values visualization library.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import missingno as msno

# %% [markdown]
# <!-- Part 1: Analyse through code. Important part of EDA. -->
# ## 5.2 Load the csv file with the pandas

# %%
# data from csv file
df = pd.read_csv("appleAppData.csv")

# %% [markdown]
# ## 5.3 Analysing & describing the dataset

# %% [markdown]
# #### 5.3.1 View the column names

# %%
df.columns
# Out:
# Index(['App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating',
#        'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version',
#        'Price', 'Currency', 'Free', 'DeveloperId', 'Developer',
#        'Developer_Url', 'Developer_Website', 'Average_User_Rating', 'Reviews',
#        'Current_Version_Score', 'Current_Version_Reviews'],
#       dtype='object')

# %% [markdown]
# #### 5.3.2 Get a sneak peek of your data
# With just a single line of code! Quickly view the top rows or bottom rows of your dataset to get a sense of what you're working with, without having to scroll through the entire file.

# %%
df.head()
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0             4+  21993472.0                  8.0  2017-09-28T03:02:41Z
# ...

# %% [markdown]
# #### 5.3.3 Defining each column

# %% [markdown]
# A comprehensive set of information about each app is provided in the dataset related to mobile applications (apps) available on  the Apple App Store. Here's a breakdown of each column:
#
# 1. `App_Id`: A unique identifier assigned to each mobile application in the dataset.
# 2. `App_Name`: The name/title of the mobile application.
# 3. `AppStore_Url`: The URL/link to the mobile application's page on the respective app store (e.g., Apple App Store or Google Play Store).
# 4. `Primary_Genre`: The primary category or genre of the app (e.g., Games, Productivity, Social Networking, etc.).
# 5. `Content_Rating`: The age or content rating assigned to the app indicating the appropriate audience (e.g., Everyone, Teen, Mature, etc.).
# 6. `Size_Bytes`: The size of the app in bytes, indicating the amount of storage space it occupies on a device.
# 7. `Required_IOS_Version`: The minimum iOS version required for the app to run on Apple devices.
# 8. `Released`: The date when the app was initially released or made available for download.
# 9. `Updated`: The date of the most recent update or version release of the app.
# 10. `Version`: The version number of the app (e.g., 1.0, 2.5.3, etc.).
# 11. `Price`: The price of the app, if not free.
# 12. `Currency`: The currency in which the app's price is listed.
# 13. `Free`: A flag or indicator whether the app is free or not (e.g., True/False).
# 14. `DeveloperId`: A unique identifier for the developer of the app.
# 15. `Developer`: The name of the developer or development company behind the app.
# 16. `Developer_Url`: The URL/link to the developer's profile or page.
# 17. `Developer_Website`: The URL/link to the developer's official website.
# 18. `Average_User_Rating`: The average rating given by users who have downloaded and used the app.
# 19. `Reviews`: The number of user reviews/ratings submitted for the app.
# 20. `Current_Version_Score`: The current average rating score for the most recent version of the app.
# 21. `Current_Version_Reviews`: The number of user reviews/ratings specific to the most recent version of the app.

# %% [markdown]
# #### 5.3.4 To check metadata of the features

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 1230376 entries, 0 to 1230375
#
# Data columns (total 21 columns):
#
#  #   Column                   Non-Null Count    Dtype
#
# ---  ------                   --------------    -----
#
#  0   App_Id                   1230376 non-null  object
#
#  1   App_Name                 1230375 non-null  object
#
#  2   AppStore_Url             1230376 non-null  object
#
#  3   Primary_Genre            1230376 non-null  object
#
#  4   Content_Rating           1230376 non-null  object
#
#  5   Size_Bytes               1230152 non-null  float64
#
#  6   Required_IOS_Version     1230376 non-null  object
#
#  7   Released                 1230373 non-null  object
#
#  8   Updated                  1230376 non-null  object
#
#  9   Version                  1230376 non-null  object
#
#  10  Price                    1229886 non-null  float64
#
#  11  Currency                 1230376 non-null  object
#
# ...

# %% [markdown]
# #### 5.3.4 To check shape (rows and columns)

# %%
df.shape
# Out:
# (1230376, 21)

# %% [markdown]
# #### 5.3.5 Missing values in the data

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Developer_Website          643988
# Developer_Url                1109
# Price                         490
# Size_Bytes                    224
# Released                        3
# App_Name                        1
# Free                            0
# Current_Version_Score           0
# Reviews                         0
# Average_User_Rating             0
# Developer                       0
# DeveloperId                     0
# App_Id                          0
# Currency                        0
# Version                         0
# Updated                         0
# Required_IOS_Version            0
# Content_Rating                  0
# Primary_Genre                   0
# AppStore_Url                    0
# Current_Version_Reviews         0
# dtype: int64

# %% [markdown]
# Write percentage of the NANs values.

# %%
# Calculate the percentage of missing values in each column
df.isnull().sum().sort_values(ascending = False)/len(df)*100
# Out:
# Developer_Website          52.340748
# Developer_Url               0.090135
# Price                       0.039825
# Size_Bytes                  0.018206
# Released                    0.000244
# App_Name                    0.000081
# Free                        0.000000
# Current_Version_Score       0.000000
# Reviews                     0.000000
# Average_User_Rating         0.000000
# Developer                   0.000000
# DeveloperId                 0.000000
# App_Id                      0.000000
# Currency                    0.000000
# Version                     0.000000
# Updated                     0.000000
# Required_IOS_Version        0.000000
# Content_Rating              0.000000
# Primary_Genre               0.000000
# AppStore_Url                0.000000
# Current_Version_Reviews     0.000000
# dtype: float64

# %%
# Plot missing values with a bar chart
msno.bar(df)
plt.show()

# %% [markdown]
# We see that developer websites have maximum number of null values. it is not reasonable to omit this column as we will loose other available values. Therefore best is to impute this with not available tag. As for Developer_Url that has considerably less missing values we can find them by searching for their developers in rest of the data where they may have provided url.

# %% [markdown]
# Drop na of developer website but write that they need to provide the website.

# %%
df["Developer_Website"]
# Out:
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4            http://imonstersoft.com
#                      ...
# 1230371                          NaN
# 1230372      https://securexvpn.com/
# 1230373    http://bee-labs.github.io
# 1230374         https://aisoftech.vn
# 1230375                          NaN
# Name: Developer_Website, Length: 1230376, dtype: object

# %% [markdown]
# To impute Developer_Website is not possible so we'll delete the column as the chunk size is more 52% so it is not wise to delete the only rows.

# %%
df.pop('Developer_Website')
# Out:
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4            http://imonstersoft.com
#                      ...
# 1230371                          NaN
# 1230372      https://securexvpn.com/
# 1230373    http://bee-labs.github.io
# 1230374         https://aisoftech.vn
# 1230375                          NaN
# Name: Developer_Website, Length: 1230376, dtype: object

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Developer_Url              1109
# Price                       490
# Size_Bytes                  224
# Released                      3
# App_Name                      1
# Free                          0
# Current_Version_Score         0
# Reviews                       0
# Average_User_Rating           0
# Developer                     0
# DeveloperId                   0
# App_Id                        0
# Currency                      0
# Version                       0
# Updated                       0
# Required_IOS_Version          0
# Content_Rating                0
# Primary_Genre                 0
# AppStore_Url                  0
# Current_Version_Reviews       0
# dtype: int64

# %%
df[df["App_Name"].isna()]
# Out:
#                 App_Id App_Name  \
# 964888  se.promedia.NA      NaN
#
#                                              AppStore_Url Primary_Genre  \
# 964888  https://apps.apple.com/us/app/na/id449134868?uo=4          News
#
#        Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 964888             4+  19528704.0                  9.0  2011-08-08T11:45:30Z
#
#                      Updated Version  Price Currency  Free  DeveloperId  \
# 964888  2020-12-21T14:08:02Z   8.1.2    0.0      USD  True    449134871
#
#        Developer                                      Developer_Url  \
# 964888  Promedia  https://apps.apple.com/us/developer/promedia/i...
#
#         Average_User_Rating  Reviews  Current_Version_Score  \
# 964888                  5.0        1                    5.0
#
#         Current_Version_Reviews
# 964888                        1

# %% [markdown]
# Since only name is missing but rest of the details are provided so we searched its Appstore url to confirm if its legit and we found the name of App "NA". So we didn't loose data.

# %%
df["App_Name"].fillna("NA", inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Developer_Url              1109
# Price                       490
# Size_Bytes                  224
# Released                      3
# Currency                      0
# Current_Version_Score         0
# Reviews                       0
# Average_User_Rating           0
# Developer                     0
# DeveloperId                   0
# Free                          0
# App_Id                        0
# App_Name                      0
# Version                       0
# Updated                       0
# Required_IOS_Version          0
# Content_Rating                0
# Primary_Genre                 0
# AppStore_Url                  0
# Current_Version_Reviews       0
# dtype: int64

# %%
df[df["Released"].isna()]
# Out:
#                                                App_Id  \
# 264853  com.ironhidegames.frontiers.universal.premium
# 836858                    com.redgamesco.transformers
# 919513    com.crayolallc.crayola-create-and-play-plus
#
#                             App_Name  \
# 264853    Kingdom Rush Frontiers TD+
# 836858  Transformers: Tactical Arena
# 919513      Crayola Create and Play+
#
#                                              AppStore_Url Primary_Genre  \
# 264853  https://apps.apple.com/us/app/kingdom-rush-fro...         Games
# 836858  https://apps.apple.com/us/app/transformers-tac...         Games
# 919513  https://apps.apple.com/us/app/crayola-create-a...         Games
#
#        Content_Rating  Size_Bytes Required_IOS_Version Released  \
# 264853            12+         NaN                 13.0      NaN
# 836858             9+         NaN               13.5.0      NaN
# 919513             4+         NaN                   13      NaN
#
# ...

# %% [markdown]
# As we see the Size_Bytes are also missing along with Released and since only 3 enteries so we can drop these rows from data.Moreover, there are no associated rating, reviews current version scores and reviews are provided therefore it is appropriate to drop these rows.

# %%
df.dropna(subset=['Released'], inplace=True)

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Developer_Url              1109
# Price                       487
# Size_Bytes                  221
# Currency                      0
# Current_Version_Score         0
# Reviews                       0
# Average_User_Rating           0
# Developer                     0
# DeveloperId                   0
# Free                          0
# App_Id                        0
# App_Name                      0
# Version                       0
# Updated                       0
# Released                      0
# Required_IOS_Version          0
# Content_Rating                0
# Primary_Genre                 0
# AppStore_Url                  0
# Current_Version_Reviews       0
# dtype: int64

# %% [markdown]
# As Developer_Url is a big chunk remaining we may loose other data if we delete these rows and since there might be url available in other rows available so we may find their unique developer ids and fill na. If not we will replace missing values with Not Provided.

# %% [markdown]
# So we checked if there are other apps of the developers with these ids to find the URL in other rows. To find that we have to check the duplicates.

# %%
df['DeveloperId'].duplicated().any()
# Out:
# True

# %% [markdown]
# There is, so lets check how many?

# %%
df['DeveloperId'].duplicated().sum()
# Out:
# 721088

# %%
df['DeveloperId'].nunique()
# Out:
# 509285

# %%
len(df['DeveloperId'])
# Out:
# 1230373

# %%
1230373 - 509285
# Out:
# 721088

# %% [markdown]
# Therefore we can find Developer URL based on unique developer IDs against missing values.

# %%
df2 = df[['DeveloperId', 'Developer_Url']].copy()
df2.fillna(df2.groupby('DeveloperId').ffill())
df2['Developer_Url'].isna().sum()
# Out:
# 1109

# %% [markdown]
# But we found no matching developers ID against the missing URL in other rows so we'll replace missing values with label "Not Provided"

# %% [markdown]
# Since we could not find missing URL. Theefore we will choose to place not provided tag in the place of NAN instead of loosing rest of important details. Just like we did with Developer website. We will keep it so the rest of the available URLs can be accessible.

# %% [markdown]
# <!-- To impute Developer_Url is not possible so we'll only delete the rows with missing values as the chunk size is small so it is not wise to delete the whole column.  -->

# %%
df["Developer_Url"].fillna("Not Provided", inplace=True)
df["Developer_Url"]
# Out:
# 0          https://apps.apple.com/us/developer/hkbu-arc/i...
# 1          https://apps.apple.com/us/developer/roman-dmit...
# 2          https://apps.apple.com/us/developer/terp-as/id...
# 3          https://apps.apple.com/us/developer/i-editeur-...
# 4          https://apps.apple.com/us/developer/ngov-chihe...
#                                  ...
# 1230371    https://apps.apple.com/us/developer/led-techno...
# 1230372    https://apps.apple.com/us/developer/trust-vpn-...
# 1230373    https://apps.apple.com/us/developer/luu-minh/i...
# 1230374    https://apps.apple.com/us/developer/th%C3%A1i-...
# 1230375    https://apps.apple.com/us/developer/pham-thanh...
# Name: Developer_Url, Length: 1230373, dtype: object

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Price                      487
# Size_Bytes                 221
# Currency                     0
# Current_Version_Score        0
# Reviews                      0
# Average_User_Rating          0
# Developer_Url                0
# Developer                    0
# DeveloperId                  0
# Free                         0
# App_Id                       0
# App_Name                     0
# Version                      0
# Updated                      0
# Released                     0
# Required_IOS_Version         0
# Content_Rating               0
# Primary_Genre                0
# AppStore_Url                 0
# Current_Version_Reviews      0
# dtype: int64

# %% [markdown]
# Now we are left with only Price and Size_Bytes.

# %% [markdown]
# #### 5.2.8 Descriptive Statistics
# We use descriptive statistics to summarize and understand the key features of dataset.

# %%
df.describe()
# Out:
#          Size_Bytes         Price   DeveloperId  Average_User_Rating  \
# count  1.230152e+06  1.229886e+06  1.230373e+06         1.230373e+06
# mean   7.510857e+07  5.041264e-01  1.092868e+09         1.788391e+00
# std    2.318726e+08  6.869674e+00  4.090898e+08         2.154106e+00
# min    2.762800e+04  0.000000e+00  2.816565e+08         0.000000e+00
# 25%    2.041344e+07  0.000000e+00  7.381079e+08         0.000000e+00
# 50%    4.333158e+07  0.000000e+00  1.179711e+09         0.000000e+00
# 75%    8.365466e+07  0.000000e+00  1.471960e+09         4.333330e+00
# max    7.677945e+10  9.999900e+02  1.590233e+09         5.000000e+00
#
#             Reviews  Current_Version_Score  Current_Version_Reviews
# count  1.230373e+06           1.230373e+06             1.230373e+06
# mean   8.259498e+02           1.788391e+00             8.259498e+02
# std    5.016057e+04           2.154106e+00             5.016057e+04
# min    0.000000e+00           0.000000e+00             0.000000e+00
# ...

# %% [markdown]
# Both Price and Size_Bytes are numeric column. so we can impute their missing values with mean.

# %%
df['Price'] = df.Price.fillna(value=df['Price'].mean())
df['Size_Bytes'] = df.Size_Bytes.fillna(value=df['Size_Bytes'].mean())

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# App_Id                     0
# App_Name                   0
# Current_Version_Score      0
# Reviews                    0
# Average_User_Rating        0
# Developer_Url              0
# Developer                  0
# DeveloperId                0
# Free                       0
# Currency                   0
# Price                      0
# Version                    0
# Updated                    0
# Released                   0
# Required_IOS_Version       0
# Size_Bytes                 0
# Content_Rating             0
# Primary_Genre              0
# AppStore_Url               0
# Current_Version_Reviews    0
# dtype: int64

# %% [markdown]
# Now we have cleaned data since we have no missing values and duplicates in the dataframe as a whole.

# %% [markdown]
# Now we pose some questions here to analyse the data and get some useful insights:

# %% [markdown]
# Lets start with
#
# 1. Top 10 paid developers with their Apps

# %%
df["Free"].nunique()
# Out:
# 2

# %%
df["Price"]
# Out:
# 0          0.00
# 1          0.00
# 2          0.00
# 3          2.99
# 4          0.00
#            ...
# 1230371    0.00
# 1230372    0.00
# 1230373    0.00
# 1230374    0.00
# 1230375    0.00
# Name: Price, Length: 1230373, dtype: float64

# %%
df_paid= df[df["Free"]==False]
sorted_df = df_paid.sort_values('Price', ascending=False)
top_paid_developers = sorted_df.head(10)

# %%
top_paid_developers
# Out:
#                                        App_Id                        App_Name  \
# 87620                  com.kanal.magnetvision                   MagnetVision™
# 1022813          com.yourcrawlspace.ycssketch                      YCS Sketch
# 482113                com.acespritech.pos-V13             ASPL POS (Odoo V13)
# 707360   com.mayfonkathletic.vert-team-system                VERT Team System
# 973050                      com.tapjets.pilot  Plane Factor - Private Jet Ops
# 1110773               com.motionics.TowerGage                      Tower Gage
# 1020170      com.vertigo.shottracertournament               Shot Tracer Event
# 482114                com.acespritech.pos-V14             ASPL POS (Odoo V14)
# 1086244             com.motionics.VibraShaker          Shale Shaker Vibration
# 935957                 com.reyburn.cybertuner                      CyberTuner
#
#                                               AppStore_Url     Primary_Genre  \
# ...

# %%
top_paid_developers[["Developer","App_Name","Primary_Genre"]]
# Out:
#                                          Developer  \
# 87620             Advanced Magnetic Analytics, LLC
# 1022813                           Your Crawl Space
# 482113       ACESPRITECH SOLUTIONS PRIVATE LIMITED
# 707360                       Mayfonk Athletic, LLC
# 973050                                     Tapjets
# 1110773                              Motionics LLC
# 1020170  Visual Vertigo Software Technologies GmbH
# 482114       ACESPRITECH SOLUTIONS PRIVATE LIMITED
# 1086244                              Motionics LLC
# 935957                 Reyburn Piano Service, Inc.
#
#                                App_Name     Primary_Genre
# 87620                     MagnetVision™           Medical
# 1022813                      YCS Sketch         Utilities
# 482113              ASPL POS (Odoo V13)          Business
# 707360                 VERT Team System  Health & Fitness
# 973050   Plane Factor - Private Jet Ops        Navigation
# ...

# %%
fig = px.bar(top_paid_developers, x='Developer', y='Price', title='Top Paid Developer',color="App_Name", labels="Primary_Genre")
fig.show()

# %% [markdown]
# 6. Top 10 apps with biggest size? consumes more space

# %%
df['Size_Bytes']
# Out:
# 0          21993472.0
# 1          13135872.0
# 2          21943296.0
# 3          81851392.0
# 4          64692224.0
#               ...
# 1230371    16666624.0
# 1230372    39016448.0
# 1230373    17223680.0
# 1230374    56716288.0
# 1230375    85135360.0
# Name: Size_Bytes, Length: 1230373, dtype: float64

# %%
df['Size_MB'] = df['Size_Bytes'].apply(lambda x: (float(x) / 1024)/1024)

# %%
# find the top 10 biggest sizes
top_10_sizes =df['Size_MB'].nlargest(10)
top_10_rows = df.loc[top_10_sizes.index]
top_10_rows
# Out:
#                                             App_Id  \
# 778214                com.kochmedia.MetroExodusNew
# 762097       com.feralinteractive.rometwremastered
# 128518                   com.aspyr.mafia3.appstore
# 762101           com.feralinteractive.warhammer2tw
# 762099        com.feralinteractive.threekingdomstw
# 668555              com.feralinteractive.dirtrally
# 676183         com.feralinteractive.lifeisstrange2
# 863396       com.feralinteractive.companyofheroes2
# 663320  com.feralinteractive.shadowofthetombraider
# 668510                  com.feralinteractive.dirt4
#
#                               App_Name  \
# 778214                    Metro Exodus
# 762097      Total War: ROME REMASTERED
# 128518                       Mafia III
# 762101         Total War: WARHAMMER II
# 762099       Total War: THREE KINGDOMS
# 668555                      DiRT Rally
# 676183               Life is Strange 2
# 863396  Company of Heroes 2 Collection
# ...

# %%
top_10_rows[["App_Name","Size_MB"]]
# Out:
#                               App_Name       Size_MB
# 778214                    Metro Exodus  73222.591724
# 762097      Total War: ROME REMASTERED  55966.684362
# 128518                       Mafia III  46456.905587
# 762101         Total War: WARHAMMER II  45104.025642
# 762099       Total War: THREE KINGDOMS  43870.335733
# 668555                      DiRT Rally  42760.803113
# 676183               Life is Strange 2  40410.851272
# 863396  Company of Heroes 2 Collection  40105.749650
# 663320       Shadow of the Tomb Raider  36724.346972
# 668510                          DiRT 4  35358.327187

# %%
# cat_totals.plot(kind="barh", fontsize=4)
fig = px.pie(top_10_rows,
              names="App_Name",
              values="Size_MB",
              hover_data=['Developer'],
              labels="Developer")

fig.update_traces(hoverinfo='label+percent', textinfo='value', textfont_size=7)

# Render the chart.
fig.show()

# %% [markdown]
# 7. Top 10 Apps and their developers with highest current version scores

# %%
# find the top 10 biggest sizes
top_10_apps_scores =df['Current_Version_Score'].nlargest(10)
top_10_rows_scorewise = df.loc[top_10_apps_scores.index]
top_10_rows_scorewise[["App_Name","Developer","Current_Version_Score"]]
# Out:
#                                     App_Name  \
# 1                                    A-Books
# 20  Aaabc Vui Lite - Bang chu cai tieng viet
# 21             AAA³ Little Ponies & Unicorns
# 24                                  B&B Cafe
# 28                                AAB Mobile
# 32                       Aakkospeli Lapsille
# 33                       Aalisiri Audiobooks
# 39              Aarti Bhajan Chalisa Sangrah
# 54                            B.E.S.T. Exams
# 57             B737-700/800 Type Rating Prep
#
#                            Developer  Current_Version_Score
# 1                     Roman Dmitriev                    5.0
# 20  Gentouch Studios Company Limited                    5.0
# 21                   Jochen Heizmann                    5.0
# 24                    Besfort Polisi                    5.0
# 28                   Nusret Bilallaj                    5.0
# 32              JH Digital Solutions                    5.0
# ...

# %%
fig = px.bar(top_10_rows_scorewise, y="App_Name",x="Developer", color="Current_Version_Score" )
fig.show()

# %% [markdown]
# Which top 5 apps and their developers has most number of reviews?

# %%
# find the top 10 biggest sizes
top_10_apps_reviews =df['Reviews'].nlargest(10)
top_10_rows_reviews = df.loc[top_10_apps_reviews.index]
top_10_rows_reviews[["App_Name","Developer","Reviews"]]
# Out:
#                                App_Name            Developer   Reviews
# 415817   YouTube: Watch, Listen, Stream           Google LLC  22685334
# 996310                        Instagram      Instagram, Inc.  21839585
# 647929   Spotify New Music and Podcasts         Spotify Ltd.  18893225
# 483342                            Venmo                Venmo  12634191
# 580482         DoorDash - Food Delivery       DoorDash, Inc.  12517538
# 456470                           TikTok     TikTok Pte. Ltd.  10598509
# 961751                             Lyft           Lyft, Inc.  10241777
# 1136477              WhatsApp Messenger        WhatsApp Inc.   9090956
# 933632        Pandora: Music & Podcasts  Pandora Media, Inc.   8297798
# 22346                             Bible          Life.Church   7181127

# %%
fig = px.bar(top_10_rows_reviews, y="App_Name",x="Developer", color="Reviews")
fig.show()

# %% [markdown]
# 2. Trend of P.G with time? which PG is progressing with time?

# %%
df['Released'] = pd.to_datetime(df['Released']) 
# convert to datetime format
df['Year_Release'] = df['Released'].dt.strftime('%Y')

# %%
# Assuming your DataFrame is named 'df' and the columns are named 'column1' and 'column2'
df_counts = df.groupby('Year_Release')["Primary_Genre"].value_counts().reset_index(name="count")
df_counts_5y = df_counts[df_counts["Year_Release"] >= "2015"]
# df_counts_5y = df_counts[df_counts["Year_Release"] >= "2015" & df_counts["count"] >= "2015"]

# %%
df_counts_5y
# Out:
#     Year_Release      Primary_Genre  count
# 172         2015              Games  16009
# 173         2015          Education   8600
# 174         2015           Business   7077
# 175         2015          Utilities   5482
# 176         2015          Lifestyle   5158
# ..           ...                ...    ...
# 354         2022      Entertainment      8
# 355         2022   Health & Fitness      1
# 356         2022       Productivity      1
# 357         2022  Social Networking      1
# 358         2022          Utilities      1
#
# [187 rows x 3 columns]

# %% [markdown]
# Since we have very few data in year 2022 we'll only focus on the previous years.

# %%
df_counts_5y = df_counts[df_counts['Year_Release'].between("2011", "2021")]

# %%
# Assuming your DataFrame is named 'df' and the columns are named 'year', 'student', and 'score'
top_PG = df_counts_5y.groupby('Year_Release').apply(lambda x: x.nlargest(5, 'count')).reset_index(drop=True)

# Print the top students
print(top_PG)
# Out:
#    Year_Release Primary_Genre  count
#
# 0          2011         Games   2919
#
# 1          2011     Education   2352
#
# 2          2011     Utilities   1536
#
# 3          2011      Business   1221
#
# 4          2011         Music   1180
#
# 5          2012         Games   4520
#
# 6          2012     Education   3705
#
# 7          2012      Business   2133
#
# 8          2012     Utilities   1999
#
# 9          2012     Lifestyle   1749
#
# 10         2013         Games   7263
#
# 11         2013     Education   5064
#
# 12         2013      Business   3400
#
# 13         2013     Utilities   2683
#
# 14         2013     Lifestyle   2351
#
# 15         2014         Games  11415
#
# 16         2014     Education   6445
#
# 17         2014      Business   4891
#
# 18         2014     Utilities   3846
#
# 19         2014     Lifestyle   3375
#
# 20         2015         Games  16009
#
# 21         2015     Education   8600
#
# 22         2015      Business   7077
#
# ...

# %%
# # Plot with Plotly
fig = px.bar(top_PG, x='Year_Release', y='count', color='Primary_Genre', barmode='group')
fig.update_layout(title='Top 5 Primary_Genre for last few Years', xaxis_title='Year_Release', yaxis_title='count')
fig.show()

# %% [markdown]
# # 6.0 Summary

# %% [markdown]
# The EDA exercise conducted on the Apple App Store dataset has yielded numerous interesting insights. The dataset was found to be relatively clean and consistent throughout the analysis. We posed several questions to the dataset and provided detailed answers and findings as follows:
#
# 1. Growth trend of Apps according to their Primary Genres from past few years.
# 2. Top 5 Apps and their developers w.r.t number of reviews.
# 3. Top 10 Apps and their developers with highest current version scores
# 4. Top 10 apps with biggest size? consumes more space
# 5. Top 10 paid developers with their Apps

# %% [markdown]
# # 7.0 Conclusion & Findings

# %% [markdown]
# The primary goal of this project is to analyze the Apple App Store dataset and identify insights based on the data. By doing so, we aim to project customer dynamics and demands to developers and relevant stakeholders, helping them generate more business for their upcoming applications.
# During this EDA exercise, we have achieved several milestones:
#
# We have cleaned the dataset from null values.
# No duplications have been found. Although the app names have duplications, they are unique records with different versions, AppIds, and release dates.
# Our findings include:
#
# <!-- Gaming apps are the most downloaded apps from the store.
# The top 10 highest rated primary genres based on average user ratings are Weather, Games, Photo & Videos, Music, and Books.
# It is important to note that the information stored in the content rating attribute may not always be reliable. There is a possibility that an app rated for 9+ may contain unsuitable topics, such as e-books. -->
